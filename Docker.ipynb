# %% [markdown]
# <a href="https://colab.research.google.com/github/Kriti-Anukriti/9thAug-pwskills/blob/main/Docker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use official Python image as base
FROM python:3.9-slim

# Set working directory inside container
WORKDIR /app

# Copy everything from current folder to container
COPY . /app

# Command to run your app
CMD ["python", "app.py"]

# %% [markdown]
# 1. Install Docker and create Dockerfiles to containerize applications?
#
# C:\Users\anukr>docker --version
# Docker version 28.0.1, build 068a01e
#
# and Docker commands for container
#
# docker build -t my-python-app
# docker run my-python-app
#
# Please find below Screenshot
# C:\Users\anukr>
# ![image.png](data:image/png;base64,...)![image.png]()
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
