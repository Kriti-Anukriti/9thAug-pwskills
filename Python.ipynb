# %% [markdown]
# <a href="https://colab.research.google.com/github/Kriti-Anukriti/9thAug-pwskills/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. Object-Oriented - Python supports classes and objects, making it easy to model real-world problems.
2. Portable - Write code once, run it anywhere — no need to change much when moving between systems.
3. Easy to Read and Write - which helps beginners understand more quickly.
4. Free and Open Source - Python is free to download and use. Its source code is open, so anyone can contribute.
5. Embeddable - - Python code can be embedded inside other languages (like C/C++) to add scripting features.
6. Interpreted Language - No need to compile Python code. It runs line by line, which makes testing and debugging easier.
7. Large Standard Library  - Python comes with many built‑in modules(NumPy, Pandas) so we don’t have to write everything from scratch, just need to import the modules
8. Dynamic Typing - we don’t need to declare variable types. Python decides the type at runtime.

# %%
QUES : Describe the Role of pre-defined Keywords in python and provide examples of how they are used in a program
ANS : "Keywords" are Reserved Words with Fixed Meaning which one cannot use as variable.
Examples If , Else , for, While , Def , class , TRUE , FALSE

How they are been Used in program:

Example no 1 - if, Else

Age = 18
if Age >=18:
      print("person is adult")

else:
      print("Person is not adult")
### it will check the age if grater than 18 it will say person is an adult.


Example No 2.

for which is also known as loop in programing lang
for i in range(10);
print(i)
#### it will print till 10

# %% [markdown]
# Ques : Explain the key features of Python that make it a popular choice for programming ?
# Ans :
# - Object Oriented
# - Portable
# - Easy to Read and Write
# - Free and Open Source
# - Embeddable
# - Interpreted Language
# - Large Standard library
# - Dynamic Typing
#
#
#
#
#
# QUES : Describe the Role of pre-defined Keywords in python and provide examples of how they are used in a program
# ANS : "Keywords" are Reserved Words with Fixed Meaning which one cannot use as variable.
# Examples If , Else , for, While , Def , class , TRUE , FALSE
#
# How they are been Used in program:
#
# Example no 1 - if, Else
#
# Age = 18
# if Age >=18:
#       print("person is adult")
#
# else:
#       print("Person is not adult")
# ### it will check the age if grater than 18 it will say person is an adult.
#
#
# Example No 2.
#
# for which is also known as loop in programing lang
# for i in range(10);
# print(i)
# #### it will print till 10
#
#
#
# QUES : Compare and constrast mutable and immutable object in python with example
# ANS : Mutuable - Can be Changed after creation Example are list dict , set
# Example
#
# n=[2,4,6]
# n.append(4)
#
# now when we will check the value of n it will be [2,4,6,4]
#
#
# Immutable - Cannot be changed once created .
# Examples like tuple
#
# name ="kriti"
# new_name =name.replace("K", "a")
# print (name)
# print(new_name)
# here name will not be changed the new changes will reflect in the value of new variable.
#
#
# QUES : Discuss the different types of operators in python and provide examples of how they are used.
# ANS : there are many operators will list of few.
# - Arithmatic - used to assign values and update variable.
# example a, b = 1, 2
# print(a+b)  answer will be 3
# print(a%b) answer will be 0
#
# - Relational operator - Used to compare the values
# Example
# a,b = 6,8
# print(a == b)  ## FALSE
# print (a<b) ## true
#
# - Logical Operator - used to combining the conditions
# Examples AND, OR , NOT
#
# - Assignment Operator - used to assign the values or update the chnage in variable values
# Example = , +=, =+ , /= etc
#
# num=5
# num +=5
# print(num)
#
# - Bitwise operator - its used to work wity binary numbers.
# example &, |, ^ , >>
#
# a , b = 6, 3
# print(a & b)
# print(a | b)
#
#
#
# QUES : Explain the concept of type casting in python with example.
# ANS : implicit Type casting - This is used when a smaller data type is converted into bigger data type , normally its happend automatically.
#
#
# Example
# x= 5
# y= 2.5
# z= x+y
# print(z)
#
# Explicity type casting - Reverse of implicit in this when we convert bigger datatype to smaller datatype and its Done  manully using build in functions;
#
# example
# a = "15"
# print(int(a)+10)
#
#
# QUES : How do Conditional Statement work in python ? illustrate with example.
# ANS : They Normally are considered as decision maker in program there output mostly in boolean TRUE or FALSE.
#
# Example
# We need to check if a student has passed or not on basis of conditions.
# marks = 70
# if marks >= 60
#    print("pass")
#
#    else:
#    print("FAIL")
#
#
# QUES : Describe the different types of loops in python and thier use cases with example.
# ANS : The main loops which we use on daily basis in python are below:
#
# For loop :  used when one block of code we want to use in repeat.
# example
# for i in range(10)
# print(i)   ### print from 1 to 10 one by one
#
#
# While loop : its used a block of code unless and untill the condition is satisfied/ TRUE
# Example
#
# x=0
# while x =6:
# print("count")
# count ++
#
#
# if else loop/ If else if else(also known as nested loop)- check if the condition is true or false and proceed to next code on that basis.
#
# Example
# marks =70
# if marks >=60
# print("pass")
# else:
# print("FAIL")
#
#
# loop control : We have this in order to have control on the ongoing loops
# like
# Break - exit the loop
# continue - skips the condition and move to the next conditions
#
# example
# for a in range(6):
# if a == 3:
# break
# print(a)
